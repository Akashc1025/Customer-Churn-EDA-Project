# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\HP\Desktop\AKASH CHIMBILI\libraries project\Customer Churn.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head(3)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# ...

# %%
df["TotalCharges"]=df["TotalCharges"].replace(" ","0")
df["TotalCharges"]=df["TotalCharges"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7043.000000
# mean     32.371149       64.761692   2279.734304
# std      24.559481       30.090047   2266.794470
# min       0.000000       18.250000      0.000000
# 25%       9.000000       35.500000    398.550000
# 50%      29.000000       70.350000   1394.550000
# 75%      55.000000       89.850000   3786.600000
# max      72.000000      118.750000   8684.800000

# %% [markdown]
# # converted 0 and 1 to yes and no

# %%
# def cov(value):
#     if value == 1:
#         return "yes"
#     else:
#         return "No"
# # many more posibilites
# df['SeniorCitizen']=df["SeniorCitizen"].apply(cov)
# df['SeniorCitizen'] = df['SeniorCitizen'].apply(lambda x: "Yes" if x == 1 else "No")
# df['SeniorCitizen'] = df['SeniorCitizen'].map({1: "Yes", 0: "No"})
# df['SeniorCitizen'] = np.where(df['SeniorCitizen'] == 1, "Yes", "No")
# df['SeniorCitizen'] = df['SeniorCitizen'].replace({1: "Yes", 0: "No"})

# %%
df.head(3)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# ...

# %%
#df.to_csv(r"C:\Users\HP\Desktop\AKASH CHIMBILI\libraries project\Customer Churn.csv", index=False)

# %%
ax=sns.countplot(x=df["Churn"],data=df)
ax.bar_label(ax.containers[0])
plt.title("count of customer by churn")
# Out:
# Text(0.5, 1.0, 'count of customer by churn')

# %%
plt.figure(figsize=(4,4))
gp=df.groupby("Churn").agg({"Churn":"count"})
plt.title("percentage of churn customer" ,fontsize=10)
plt.pie(gp["Churn"],  labels=gp.index  ,  autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x274bdaf97f0>,
# ...
#  [Text(-0.7393678155529122, 0.8144539479458092, 'No'),
#   Text(0.7393680809356542, -0.8144537070291521, 'Yes')],
#  [Text(-0.40329153575613386, 0.4442476079704413, '73.46%'),
#   Text(0.4032916805103568, -0.44424747656135566, '26.54%')])

# %%
na=sns.countplot(x="gender",data=df,hue=("Churn"))
na.bar_label(na.containers[0])
# Out:
# [Text(0, 0, '2549'), Text(0, 0, '2625')]

# %%
ax=sns.countplot(x=df["SeniorCitizen"],data=df)
ax.bar_label(ax.containers[0])
plt.title("count of customer by churn")
# Out:
# Text(0.5, 1.0, 'count of customer by churn')

# %%
# Step 1: Group by SeniorCitizen (Yes/No) and Churn
counts = df.groupby(["SeniorCitizen", "Churn"]).size().reset_index(name="count")

# Step 2: Convert to percentage
counts["percentage"] = counts.groupby("SeniorCitizen")["count"].transform(lambda x: x / x.sum() * 100)

# Step 3: Pivot for stacked bar
pivot = counts.pivot(index="SeniorCitizen", columns="Churn", values="percentage").fillna(0)

# Step 4: Plot stacked bar with Yes/No on X-axis
ax = pivot.plot(kind="bar", stacked=True, figsize=(6,5), color=['#1f77b4','#ff7f0e'])

# Step 5: Add percentage labels
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="center")

plt.title("Senior Citizen vs Churn (Percentage Stacked)")
plt.ylabel("Percentage")
plt.xlabel("Senior Citizen")
plt.legend(title="Churn")
plt.show()

# %% [markdown]
# comparetive the grater percentage of senior people has churned out

# %%
plt.figure(figsize=(9,5))
sns.histplot(x="tenure",data=df,bins=72,hue="Churn")
plt.title("count of churned customer by tenure")
plt.show()

# %% [markdown]
# people who have stayed for months have stayed and people who have stayed for  1 to 2 months have churn clear_output

# %%
ax=sns.countplot(x=df["Contract"],data=df)
ax.bar_label(ax.containers[0])
plt.title("count of customer by Contract")
# Out:
# Text(0.5, 1.0, 'count of customer by Contract')

# %%
counts = df.groupby(["Contract", "Churn"]).size().reset_index(name="count")

# Step 2: Convert to percentage
counts["percentage"] = counts.groupby("Contract")["count"].transform(lambda x: x / x.sum() * 100)

# Step 3: Pivot for stacked bar
pivot = counts.pivot(index="Contract", columns="Churn", values="percentage").fillna(0)

# Step 4: Plot stacked bar
ax = pivot.plot(kind="bar", stacked=True, figsize=(7,5), color=['#1f77b4','#ff7f0e'])

# Step 5: Add percentage labels inside bars
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", label_type="center")

plt.title("Churn Distribution by Contract (Percentage Stacked)")
plt.ylabel("Percentage")
plt.xlabel("Contract Type")
plt.legend(title="Churn")
plt.show()

# %% [markdown]
# people who have month to month are likely to churn out then people who are 1 and 2 years of contract

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# Columns you want to plot
cols = ['PhoneService', 'MultipleLines', 'InternetService',
        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
        'TechSupport', 'StreamingTV', 'StreamingMovies']

# Set figure size (3 rows × 3 cols since you have 9 features)
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
axes = axes.flatten()  # flatten for easy iteration

# Loop through each column and create countplot
for i, col in enumerate(cols):
    sns.countplot(x=col, data=df, hue="Churn", ax=axes[i])
    axes[i].set_title(f"Count of Customers by {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")
    # Add count labels on bars
    for container in axes[i].containers:
        axes[i].bar_label(container, fontsize=8)

# Adjust layout so plots don’t overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# Phone Service: Customers without phone service churn more than those with it.
#
# Multiple Lines: Customers with multiple lines churn slightly more than those with a single line.
#
# Internet Service: Fiber optic users churn the most, while DSL users churn less.
#
# Online Security: Churn is higher among customers without online security.
#
# Online Backup: Customers without online backup are more likely to churn.
#
# Device Protection: Churn is higher when customers don’t have device protection.
#
# Tech Support: Lack of tech support is linked to higher churn rates.
#
# Streaming TV: Customers using streaming TV services show higher churn.
#
# Streaming Movies: Churn is greater among customers with streaming movie services.

# %%
ax=sns.countplot(x=df["PaymentMethod"],data=df,hue="Churn")
ax.bar_label(ax.containers[0])
plt.title(" churned  customer by payment method")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %% [markdown]
# Payment Method: Customers using electronic checks have the highest churn, while automatic payments (bank or credit card) are linked to lower churn.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Load predictions
preds_df = pd.read_csv(r"C:\Users\HP\Desktop\AKASH CHIMBILI\libraries project\customer chrun\churn_predictions (1).csv")

# Countplot of risk labels
plt.figure(figsize=(6,5))
ax = sns.countplot(x="risk_label", data=preds_df, order=["Low","Medium","High"], palette="Set2")
ax.bar_label(ax.containers[0])
plt.title("Customer Churn Risk Distribution")
plt.xlabel("Risk Category")
plt.ylabel("Number of Customers")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14464\2956579097.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="risk_label", data=preds_df, order=["Low","Medium","High"], palette="Set2")
